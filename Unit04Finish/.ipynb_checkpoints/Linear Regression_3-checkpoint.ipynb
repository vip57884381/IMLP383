# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 3. Nonlinear
#
# $$f(x) = \sin(3.2x) + 0.8x$$

# %% [markdown]
# ### 3. 生成假資料

# %%
x = np.linspace(0, 5, 100)
y = np.sin(3.2*x) + 0.8*x + 0.3*np.random.randn(100)

# %%
plt.scatter(x,y)

# %% [markdown]
# #### nonlinear

# %%
regr_lin = LinearRegression()

# %%
X = x.reshape(-1, 1)
print(X.shape)
# Out:
# (100, 1)

# %%
regr_lin.fit(X,y)
# Out:
# LinearRegression()

# %%
Y=regr_lin.predict(X)
plt.scatter(x,y)
plt.plot(x,Y , color='r')
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.5483148915870346

# %% [markdown]
# 果然超級不準, 該如何是好?

# %% [markdown]
# #### 多項式
#
# 多項式5次方

# %% [markdown]
# $$\widehat{y}=xw+b=w_{1}x_{1}+w_{2}x_{1}^{2}+w_{3}x_{1}^{3}+w_{4}x_{1}^{4}+w_{5}x_{1}^{5}+b$$

# %%
print(x.shape)
# Out:
# (100,)

# %%
X_poly = np.array([[k, k**2, k**3, k**4, k**5] for k in x])  # add k**6 to try it
print(X_poly.shape)
# Out:
# (100, 5)

# %%
regr_poly = LinearRegression()

# %%
regr_poly.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x, regr_poly.predict(X_poly), 'r')

# %%
print('Coefficients: ', regr_poly.coef_)
print('interception: ', regr_poly.intercept_)
# Out:
# Coefficients:  [-1.36531985  1.73568878 -0.65641276  0.11695189 -0.00769349]
# interception:  0.9905762569844563

# %%
W=regr_poly.coef_
b=regr_poly.intercept_
np.dot(X_poly,W.T)+b
# Out:
# array([0.99057626, 0.92596423, 0.86971005, 0.82133336, 0.78037144,
#        0.74637894, 0.71892755, 0.69760571, 0.6820183 , 0.67178633,
#        0.66654666, 0.66595168, 0.669669  , 0.67738115, 0.68878531,
#        0.70359295, 0.72152957, 0.74233437, 0.76575997, 0.79157209,
#        0.81954925, 0.84948248, 0.88117498, 0.91444187, 0.94910985,
#        0.98501688, 1.02201193, 1.05995465, 1.09871503, 1.13817319,
#        1.17821895, 1.21875165, 1.25967975, 1.30092061, 1.3424001 ,
#        1.38405238, 1.42581952, 1.46765127, 1.5095047 , 1.55134393,
#        1.59313979, 1.63486957, 1.67651668, 1.71807033, 1.75952529,
#        1.80088152, 1.8421439 , 1.88332191, 1.92442937, 1.96548408,
#        2.00650753, 2.04752462, 2.08856336, 2.12965452, 2.17083138,
#        2.21212938, 2.25358588, 2.29523976, 2.33713124, 2.37930144,
#        2.42179221, 2.46464572, 2.50790423, 2.55160972, 2.59580366,
#        2.64052665, 2.68581814, 2.73171613, 2.77825685, 2.82547447,
#        2.87340079, 2.92206495, 2.97149311, 3.02170814, 3.07272936,
#        3.12457217, 3.17724781, 3.23076301, 3.28511973, 3.3403148 ,
#        3.39633969, 3.45318012, 3.51081584, 3.56922027, 3.62836022,
#        3.68819558, 3.74867903, 3.80975571, 3.87136295, 3.93342992,
#        3.99587739, 4.05861737, 4.12155283, 4.18457741, 4.24757508,
#        4.31041989, 4.37297559, 4.43509542, 4.49662172, 4.55738569])

# %%
regr_poly.predict(X_poly)
# Out:
# array([0.99057626, 0.92596423, 0.86971005, 0.82133336, 0.78037144,
#        0.74637894, 0.71892755, 0.69760571, 0.6820183 , 0.67178633,
#        0.66654666, 0.66595168, 0.669669  , 0.67738115, 0.68878531,
#        0.70359295, 0.72152957, 0.74233437, 0.76575997, 0.79157209,
#        0.81954925, 0.84948248, 0.88117498, 0.91444187, 0.94910985,
#        0.98501688, 1.02201193, 1.05995465, 1.09871503, 1.13817319,
#        1.17821895, 1.21875165, 1.25967975, 1.30092061, 1.3424001 ,
#        1.38405238, 1.42581952, 1.46765127, 1.5095047 , 1.55134393,
#        1.59313979, 1.63486957, 1.67651668, 1.71807033, 1.75952529,
#        1.80088152, 1.8421439 , 1.88332191, 1.92442937, 1.96548408,
#        2.00650753, 2.04752462, 2.08856336, 2.12965452, 2.17083138,
#        2.21212938, 2.25358588, 2.29523976, 2.33713124, 2.37930144,
#        2.42179221, 2.46464572, 2.50790423, 2.55160972, 2.59580366,
#        2.64052665, 2.68581814, 2.73171613, 2.77825685, 2.82547447,
#        2.87340079, 2.92206495, 2.97149311, 3.02170814, 3.07272936,
#        3.12457217, 3.17724781, 3.23076301, 3.28511973, 3.3403148 ,
#        3.39633969, 3.45318012, 3.51081584, 3.56922027, 3.62836022,
#        3.68819558, 3.74867903, 3.80975571, 3.87136295, 3.93342992,
#        3.99587739, 4.05861737, 4.12155283, 4.18457741, 4.24757508,
#        4.31041989, 4.37297559, 4.43509542, 4.49662172, 4.55738569])

# %% [markdown]
# #### RBF
#
# $$\phi_i = e^{-\| x - c_i \|^2/2\sigma^2}$$

# %%
# 常態分佈
# normal distrubution
def RBF(x, center, sigma):
    k = np.exp(-(x - center)**2/(2*sigma**2))
    return k

# %%
sigma = 0.3

# %%
X_rbf = np.array([[RBF(k, .5, sigma), 
                  RBF(k, 1.5, sigma),
                  RBF(k, 2.5, sigma),
                  RBF(k, 3.5, sigma),
                  RBF(k, 4.5, sigma)] for k in x])

# %%
# 預測
regr_rbf = LinearRegression()

# %%
regr_rbf.fit(X_rbf, y)
# Out:
# LinearRegression()

# %%
# 預測結果比較符合實際結果
plt.scatter(x,y)
plt.plot(x, regr_rbf.predict(X_rbf), 'r')

# %%
print('Coefficients: ', regr_rbf.coef_)
print('interception: ', regr_rbf.intercept_)
# Out:
# Coefficients:  [-1.02057867 -1.934629    1.23403039  0.18199506  3.13781638]
# interception:  1.9213789126759455

# %% [markdown]
# #### Comparison

# %%
# 3個方法做比較
Y_lin = regr_lin.predict(X)
Y_poly = regr_poly.predict(X_poly)
Y_rbf = regr_rbf.predict(X_rbf)

# %%
plt.scatter(x,y)

plt.plot(x, Y_lin, label='linear')
plt.plot(x, Y_poly, label='polynomial')
plt.plot(x, Y_rbf, label='rbf')
plt.legend()

# %% [markdown]
# ## 請計算模型的MSE

# %%
# 預測值-原始資料
print(np.sum((regr_lin.predict(X)-y)**2) / len(y))
# Out:
# 0.5483148915870346

# %%
# 預測值-原始資料
print(np.sum((regr_poly.predict(X_poly)-y)**2) / len(y))
# Out:
# 0.49684839164961586

# %%
# 預測值-原始資料
print(np.sum((regr_rbf.predict(X_rbf)-y)**2) / len(y))
# Out:
# 0.263395950856432
